# %%
x1 = 10.97
y1 = 112
import random
r = 0.3

data = []
for i in range(1, 20):
    d = random.random()*0.1+i*0.2
    data.append((x1-d, y1+r*d))

print(data)
# Out:
# [(10.746791554238998, 112.0669625337283), (10.551823117450262, 112.12545306476493), (10.349016399645516, 112.18629508010635), (10.160154892515656, 112.24295353224531), (9.961366565154181, 112.30259003045374), (9.690823760177398, 112.38375287194678), (9.564144149874611, 112.42175675503762), (9.344322513505912, 112.48770324594823), (9.158727258510291, 112.54338182244692), (8.912682017148873, 112.61719539485534), (8.743204538301868, 112.66803863850944), (8.49902608245854, 112.74129217526244), (8.308672054425447, 112.79839838367236), (8.109207352467454, 112.85823779425976), (7.942934822989383, 112.90811955310319), (7.700364652098475, 112.98089060437046), (7.483749351261558, 113.04587519462153), (7.355072111732291, 113.08447836648031), (7.129545519329971, 113.15213634420101)]
